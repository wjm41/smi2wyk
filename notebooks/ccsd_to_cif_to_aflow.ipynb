# %% [markdown]
# # Wyckoff from CSD Entry
#
# 12th May - A notebook for converting a CSD entry to .cif and then to an aflow label.

# %% [markdown]
# Read CSD entry and write to .cif

# %%
from ccdc import io, utilities
import re 

csd_reader = io.EntryReader('/Applications/CCDC/CSD_2022/DATA/CSD_543/as543be_ASER.sqlite')
# entry = csd_reader.entry('CAXZEG')
# entry = csd_reader.entry('ADAGES')

entry_name = 'CAXZEG'
entry = csd_reader.entry(entry_name)
crystal = entry.crystal

print(f'SMILES: {crystal.molecule.smiles}')
print(f'Crystal System: {crystal.crystal_system}')
print(f'Spacegroup Symbol: {crystal.spacegroup_symbol}')
print(f'Spacegroup Number: {crystal.spacegroup_number_and_setting}')
print(f'Has disorder: {crystal.has_disorder}')
print(f'Disorder details: {entry.disorder_details}')

elems = [re.sub("([A-Z]).*", r"\1", elem) for elem in crystal.formula.split(" ")]
print(f'Sorted elements: {sorted(elems)}')

print('\n'.join('%-17s %s' % (op, utilities.print_set(crystal.atoms_on_special_positions(op))) for op in crystal.symmetry_operators))

cif_string = crystal.to_string(format='cif')
with open('tmp.cif', 'w') as f:
    f.write(cif_string)
# Out:
# SMILES: CCCC1=C2N=C(NC(=O)C2=NN1C)c1cc(ccc1OCC)S(=O)(=O)N1CCN(C)CC1
# Crystal System: monoclinic
# Spacegroup Symbol: P21/n
# Spacegroup Number: (14, 2)
# Has disorder: False
# Disorder details: None
# Sorted elements: ['C', 'H', 'N', 'O', 'S']
# x,y,z             {Atom(C1), Atom(C10), Atom(C11), Atom(C12), Atom(C13), Atom(C14), Atom(C15), Atom(C16), Atom(C17), Atom(C18), Atom(C19), Atom(C2), Atom(C20), Atom(C21), Atom(C22), Atom(C3), Atom(C4), Atom(C5), Atom(C6), Atom(C7), Atom(C8), Atom(C9), Atom(H1), Atom(H10), Atom(H11), Atom(H12), Atom(H13), Atom(H14), Atom(H15), Atom(H16), Atom(H17), Atom(H18), Atom(H19), Atom(H2), Atom(H20), Atom(H21), Atom(H22), Atom(H23), Atom(H24), Atom(H25), Atom(H26), Atom(H27), Atom(H28), Atom(H29), Atom(H3), Atom(H30), Atom(H4), Atom(H5), Atom(H6), Atom(H7), Atom(H8), Atom(H9), Atom(N1), Atom(N2), Atom(N3), Atom(N4), Atom(N5), Atom(N6), Atom(O1), Atom(O2), Atom(O3), Atom(O4), Atom(S1)}
# 1/2-x,1/2+y,1/2-z set()
# -x,-y,-z          set()
# 1/2+x,1/2-y,1/2+z set()

# %% [markdown]
# Load pymatgen structure from .cif

# %%
from wren_code import utils
from pymatgen.core import Composition, Structure
from pymatgen.io.cif import CifParser, CifFile

class CifStringParser(CifParser):
    
    def __init__(self, cif_string, occupancy_tolerance=1.0, site_tolerance=1e-4):
        """
        Args:
            filename (str): CIF filename, bzipped or gzipped CIF files are fine too.
            occupancy_tolerance (float): If total occupancy of a site is between 1
                and occupancy_tolerance, the occupancies will be scaled down to 1.
            site_tolerance (float): This tolerance is used to determine if two
                sites are sitting in the same position, in which case they will be
                combined to a single disordered site. Defaults to 1e-4.
        """
        self._occupancy_tolerance = occupancy_tolerance
        self._site_tolerance = site_tolerance
        if isinstance(cif_string, (str,)):
            self._cif = CifFile.from_string(cif_string)
        else:
            raise TypeError('cif_string needs to be a string!')
        # store if CIF contains features from non-core CIF dictionaries
        # e.g. magCIF
        self.feature_flags = {}
        self.warnings = []
        
        def is_magcif():
            """
            Checks to see if file appears to be a magCIF file (heuristic).
            """
            # Doesn't seem to be a canonical way to test if file is magCIF or
            # not, so instead check for magnetic symmetry datanames
            prefixes = [
                "_space_group_magn",
                "_atom_site_moment",
                "_space_group_symop_magn",
            ]
            for d in self._cif.data.values():
                for k in d.data.keys():
                    for prefix in prefixes:
                        if prefix in k:
                            return True
            return False

        self.feature_flags["magcif"] = is_magcif()

        def is_magcif_incommensurate():
            """
            Checks to see if file contains an incommensurate magnetic
            structure (heuristic).
            """
            # Doesn't seem to be a canonical way to test if magCIF file
            # describes incommensurate strucure or not, so instead check
            # for common datanames
            if not self.feature_flags["magcif"]:
                return False
            prefixes = ["_cell_modulation_dimension", "_cell_wave_vector"]
            for d in self._cif.data.values():
                for k in d.data.keys():
                    for prefix in prefixes:
                        if prefix in k:
                            return True
            return False

        self.feature_flags["magcif_incommensurate"] = is_magcif_incommensurate()

        for k in self._cif.data.keys():
            # pass individual CifBlocks to _sanitize_data
            self._cif.data[k] = self._sanitize_data(self._cif.data[k])
            
struct = CifStringParser(cif_string, occupancy_tolerance=10).get_structures()[0]
# struct = CifParser('tmp.cif', occupancy_tolerance=10).get_structures()[0]
# struct = Structure.from_str(cif_string, fmt="cif", merge_tol=0.1)
wyckoff_label = utils.get_aflow_label_spglib(struct)
print(wyckoff_label)
# Out:
# A20BC6D16E4F2G_tP200_130_5g_a_2cg_4g_g_f_c:C-Cu-F-H-N-O-Ti

# %% [markdown]
# 17th May - A notebook for converting a CSD entry to aflow label using aflow directly instead of spglib

# %%
import pandas as pd

df = pd.read_csv('aflow_vs_spg.csv')
df['csd_spacegroup'] = [int(spg[0][1:]) for spg in df['csd_spacegroup'].str.split(',')]
df
# Out:
#      index identifier                                             smiles  \
# 0        0     AABHTZ         CC(=O)NN1C=NN=C1N(N=Cc1c(Cl)cccc1Cl)C(C)=O
# 1        1   AACFAZ10  COC1=C(C(OC1=O)c1ccccc1Cl)C(C)=NN=C(C)C1=C(OC)...
# 2        2   AACMHX10                CC(=O)OC(=C1CCCCC1c1ccccc1)c1ccccc1
# 3        3     AADAMC             [Br-].[NH3+]C1(C2CC3CC(C2)CC1C3)C(O)=O
# 4        4   AADMPY10  Cc1[nH+]c(N)nc(N)c1C12CC3CC(CC(C3)C1)C2.CCS(=O...
# ..     ...        ...                                                ...
# 853    103     ABZCTD               O=C1CCc2ccccc2C2C1C1C2c2ccccc2CCC1=O
# 854    104   ABZEHX10       C(OCc1ccccc1)C1OC=CC(OCc2ccccc2)C1OCc1ccccc1
# 855    105     ABZNPS         CN(C)c1ccc(CS(=O)(=O)c2ccc(cc2)N(=O)=O)cc1
# 856    106     ABZSLM                   [Cl-].[NH3+]c1cccc(c1)S(N)(=O)=O
# 857    107     ABZTCX             CN(C)C1=NS(=O)(=O)c2ccccc2C(=O)NC1(C)C
#
#      csd_spacegroup                                      wyckoff_spg  \
# 0                 2  A13B2C12D6E2_aP70_2_13i_2i_12i_6i_2i:C-Cl-H-N-O
# 1                60    A13BC11DE3_oP232_60_13d_d_11d_d_3d:C-Cl-H-N-O
# 2                61               A21B22C2_oP360_61_21c_22c_2c:C-H-O
# 3                14    AB11C18DE2_mP132_14_e_11e_18e_e_2e:Br-C-H-N-O
# 4                 2    A17B28C4D3E_aP106_2_17i_28i_4i_3i_i:C-H-N-O-S
# ..              ...                                              ...
# 853              60                 A11B10C_oP176_60_11d_10d_d:C-H-O
# 854               4                A27B28C4_mP118_4_27a_28a_4a:C-H-O
# 855               2     A15B16C2D4E_aP76_2_15i_16i_2i_4i_i:C-H-N-O-S
# 856              19  A6BC9D2E2F_oP84_19_6a_a_9a_2a_2a_a:C-Cl-H-N-O-S
# 857              14   A13B17C3D3E_mP148_14_13e_17e_3e_3e_e:C-H-N-O-S
#
#                                        wyckoff_aflow
# 0    A13B2C12D6E2_aP70_2_13i_2i_12i_6i_2i:C-Cl-H-N-O
# 1      A13BC11DE3_oP232_60_13d_d_11d_d_3d:C-Cl-H-N-O
# 2                 A21B22C2_oP360_61_21c_22c_2c:C-H-O
# 3      AB11C18DE2_mP132_14_e_11e_18e_e_2e:Br-C-H-N-O
# 4      A17B28C4D3E_aP106_2_17i_28i_4i_3i_i:C-H-N-O-S
# ..                                               ...
# 853                 A11B10C_oP176_60_11d_10d_d:C-H-O
# 854                A27B28C4_mP118_4_27a_28a_4a:C-H-O
# 855     A15B16C2D4E_aP76_2_15i_16i_2i_4i_i:C-H-N-O-S
# 856  A6BC9D2E2F_oP84_19_6a_a_9a_2a_2a_a:C-Cl-H-N-O-S
# 857   A13B17C3D3E_mP148_14_13e_17e_3e_3e_e:C-H-N-O-S
#
# [858 rows x 6 columns]

# %%
# from smi2wyk.wren_code.utils import get_aflow_label_with_aflow_from_ccdc_crystal
from string import digits
entry_name = 'ABEDOA'
entry = csd_reader.entry(entry_name)
crystal = entry.crystal
remove_digits = str.maketrans("", "", digits)

# print(crystal.formula)
elems = sorted([elem.translate(remove_digits).replace('.', '') for elem in crystal.formula.split(" ")])
print(elems)
print(entry.molecule.smiles)
print(crystal.to_string('cif'))
# wyckoff_label_aflow = get_aflow_label_with_aflow_from_ccdc_crystal(crystal)
# Out:
# ['C', 'H', 'N', 'O', 'S']
# OCCCOCC1=CSC(=N1)C1=NC(=C(S1)C1=C(COCCCO)N=C(S1)C1=NC(=CS1)COCCCO)COCCCO
#
# #######################################################################
# #
# #                 Cambridge Crystallographic Data Centre
# #                                CCDC
# #
# #######################################################################
# #
# # If this CIF has been generated from an entry in the Cambridge
# # Structural Database, then it will include bibliographic, chemical,
# # crystal, experimental, refinement or atomic coordinate data resulting
# # from the CCDC's data processing and validation procedures.
# #
# #######################################################################
#
# data_ABEDOA
# _symmetry_cell_setting           triclinic
# _symmetry_space_group_name_H-M   'P -1'
# _symmetry_Int_Tables_number      2
# _space_group_name_Hall           '-P 1'
# loop_
# _symmetry_equiv_pos_site_id
# _symmetry_equiv_pos_as_xyz
# 1 x,y,z
# 2 -x,-y,-z
# _cell_length_a                   4.99020(10)
# _cell_length_b                   9.4924(2)
# _cell_length_c                   16.9038(3)
# _cell_angle_alpha                105.9970(10)
# _cell_angle_beta                 91.4790(10)
# _cell_angle_gamma                99.2800(10)
# _cell_volume                     757.549
# loop_
# _atom_site_label
# _atom_site_type_symbol
# _atom_site_fract_x
# _atom_site_fract_y
# _atom_site_fract_z
# S1 S 0.7748(5) 0.4015(3) 0.4086(2)
# S2 S 1.2217(6) 0.6548(3) 0.2589(2)
# N1 N 0.8262(19) 0.6669(10) 0.3936(6)
# N2 N 1.2037(19) 0.3928(10) 0.2762(6)
# O1 O 1.6813(17) 0.3162(9) 0.1172(5)
# O2 O 1.7045(18) 0.1584(12) -0.1150(5)
# O3 O 0.5695(14) 0.8616(8) 0.5719(4)
# O4 O 1.1664(17) 1.0719(11) 0.8135(5)
# C1 C 0.5900(20) 0.5233(12) 0.4710(6)
# C2 C 0.6410(20) 0.6592(12) 0.4517(7)
# C3 C 0.9100(20) 0.5392(12) 0.3661(6)
# C4 C 1.1030(20) 0.5157(12) 0.3029(6)
# C5 C 1.4210(20) 0.5401(13) 0.2009(7)
# C6 C 1.3840(20) 0.4083(13) 0.2174(7)
# C7 C 1.5190(20) 0.2790(13) 0.1791(7)
# C8 C 1.8080(20) 0.1965(13) 0.0731(7)
# C9 C 1.9920(20) 0.2539(14) 0.0151(7)
# C10 C 1.8380(30) 0.2894(15) -0.0538(7)
# C11 C 0.5140(20) 0.7958(12) 0.4868(7)
# C12 C 0.8450(20) 0.9268(12) 0.5963(7)
# C13 C 0.8800(20) 0.9619(12) 0.6897(7)
# C14 C 1.1700(20) 1.0333(14) 0.7250(7)
# C1A C 0.4100(20) 0.4767(12) 0.5290(6)
# S1A S 0.2252(5) 0.5985(3) 0.5914(2)
# C3A C 0.0900(20) 0.4608(12) 0.6339(6)
# N1A N 0.1738(19) 0.3331(10) 0.6064(6)
# C2A C 0.3590(20) 0.3408(12) 0.5483(7)
# C11A C 0.4860(20) 0.2042(12) 0.5132(7)
# O3A O 0.4305(14) 0.1384(8) 0.4281(4)
# C12A C 0.1550(20) 0.0732(12) 0.4037(7)
# C13A C 0.1200(20) 0.0381(12) 0.3103(7)
# C14A C -0.1700(20) -0.0333(14) 0.2750(7)
# O4A O -0.1664(17) -0.0719(11) 0.1865(5)
# C4A C -0.1030(20) 0.4843(12) 0.6971(6)
# S2A S -0.2217(6) 0.3452(3) 0.7411(2)
# C5A C -0.4210(20) 0.4599(13) 0.7991(7)
# C6A C -0.3840(20) 0.5917(13) 0.7826(7)
# N2A N -0.2037(19) 0.6072(10) 0.7238(6)
# C7A C -0.5190(20) 0.7210(13) 0.8209(7)
# O1A O -0.6813(17) 0.6838(9) 0.8828(5)
# C8A C -0.8080(20) 0.8035(13) 0.9269(7)
# C9A C -0.9920(20) 0.7461(14) 0.9849(7)
# C10A C -0.8380(30) 0.7106(15) 1.0538(7)
# O2A O -0.7045(18) 0.8416(12) 1.1150(5)
# loop_
# _geom_bond_atom_site_label_1
# _geom_bond_atom_site_label_2
# _geom_bond_site_symmetry_1
# _geom_bond_site_symmetry_2
# S1 C1 1_555 1_555
# S2 C4 1_555 1_555
# N1 C2 1_555 1_555
# N2 C4 1_555 1_555
# O1 C7 1_555 1_555
# O2 C10 1_555 1_555
# O3 C11 1_555 1_555
# O4 C14 1_555 1_555
# C1 C2 1_555 1_555
# C2 C11 1_555 1_555
# C3 S1 1_555 1_555
# C4 C3 1_555 1_555
# C5 S2 1_555 1_555
# C6 N2 1_555 1_555
# C7 C6 1_555 1_555
# C8 O1 1_555 1_555
# C9 C8 1_555 1_555
# C10 C9 1_555 1_555
# C12 O3 1_555 1_555
# C13 C12 1_555 1_555
# C14 C13 1_555 1_555
# C1A C1 1_555 1_555
# S1A C1A 1_555 1_555
# C3A S1A 1_555 1_555
# N1A C3A 1_555 1_555
# C2A C1A 1_555 1_555
# C11A C2A 1_555 1_555
# O3A C11A 1_555 1_555
# C12A O3A 1_555 1_555
# C13A C12A 1_555 1_555
# C14A C13A 1_555 1_555
# O4A C14A 1_555 1_555
# C4A C3A 1_555 1_555
# S2A C4A 1_555 1_555
# C5A S2A 1_555 1_555
# C6A C5A 1_555 1_555
# N2A C4A 1_555 1_555
# C7A C6A 1_555 1_555
# O1A C7A 1_555 1_555
# C8A O1A 1_555 1_555
# C9A C8A 1_555 1_555
# C10A C9A 1_555 1_555
# O2A C10A 1_555 1_555
# N1 C3 1_555 1_555
# C5 C6 1_555 1_555
# N1A C2A 1_555 1_555
# C6A N2A 1_555 1_555
#
# #END

# %%
# df.wyckoff_spg = df.wyckoff_spg.str.split(':').str[0]
# df.wyckoff_aflow = df.wyckoff_aflow.str.split(':').str[0]
df.query('wyckoff_spg != wyckoff_aflow')
# Out:
#      index identifier                                             smiles  \
# 8        8     AANHOX                  COc1ccc(cc1)C=NO.COc1ccc(cc1)C=NO
# 10      10     AAPYPE                             CC(=O)C=C(C)Nc1cncnc1N
# 130     22     ABATRG  COC(=O)C1CC(CC2(C)C1CCC13CC(CCC21)C(Br)(CBr)C3...
# 151     43     ABAYIN              CCOC(CP(=O)(c1ccccc1C)c1ccccc1C)OCC.O
# 159     51     ABCMHP  CC(=O)OC1C(OC(C)=O)C(O)(CBr)OC(CCl)(CBr)C1OC(C)=O
# 164     56     ABEBAK  COC(=O)C1=C(C)NC(=C(C1c1ccc(cc1)C1=CC(=O)c2ccc...
# 177     69     ABECEP              O=C1OC(N2C3C4CC(C=C4)C3C2=O)c2ccccc12
# 181     73     ABEDIU  C=CCOCC1=CSC(=N1)C1=NC(=C(S1)C1=C(COCC=C)N=C(S...
# 184     76     ABEDOA  OCCCOCC1=CSC(=N1)C1=NC(=C(S1)C1=C(COCCCO)N=C(S...
# 260     48     ABELOL  CCOC(=O)C1CC2(C(=C)CN1S(=O)(=O)c1ccc(cc1)N(=O)...
# 290     78     ABEPEC               OC(=O)CC(c1ccccc1)(c1ccccc1)c1ccccc1
# 293     81     ABEPEF  COC(=O)C1=CC(C(C1c1ccccc1Cl)C1=NS(=O)(=O)Oc2cc...
# 294     82     ABEPIG  CC12CCC3C(CCC4=CC(=O)CCC34C)C1CCC2C(=O)CO.CC12...
# 299     87     ABEPUS                     CC1=CCC(C)(C)C2OC2CC2(C)OC2CC1
# 307     95     ABEQIH  O=P1([O-])OP(=O)([O-])OP(=O)([O-])OP(=O)([O-])...
# 329     17     ABEWOW           [I-].CC[N+]1=C(Sc2ccccc12)C=Cc1ccc(O)cc1
# 339     27     ABGPON  CC(=O)OCC1OC(OC2=C(NC(=O)c3ccccc3)C(=O)N(C2)C(...
# 340     28   ABHPHY10  CC1C(=O)OC2CC1(C)C1C(=O)C3(O)OC41C2(C)OC(=O)C4...
# 341     29     ABHPTB  CC1(C)OC2C3COC4=C(Br)c5c(N)ncnc5N4C(O3)C2O1.CC...
# 384     72     ABIJED  CC1(C)C2CC=C(C(=O)[Si](C)(C)C)C2(C#N)C(=O)c2cc...
# 391     79     ABIJUU      ClCCl.CC1(C)OC2CC(=O)OC2C(O1)C(O)C(O)c1ccccc1
# 397     85   ABILAC10  COC1CCC2(C)C3CCC4(C)C(CCC4(C)C3=CCC2C1(C)C)C(C...
# 405     93     ABIMAZ                       CC(C)C1=C(NC(C)=O)N=C(Br)N1C
# 411     99     ABIMUW  C1CCC2N=Cc3cc4C=NC5CCCCC5N=Cc5cc6C=NC7CCCCC7N=...
# 413    101     ABINAD  C1CCC2N=Cc3cc4C=NC5CCCCC5N=Cc5cc6C=NC7CCCCC7N=...
# 421      7   ABINOR02                                   OC1COC(O)C(O)C1O
# 422      8   ABINOR03                                   OC1COC(O)C(O)C1O
# 447     33     ABIRIP  CC1=CN(C2SC(CO)C(C)(CO)C2F)C(=O)NC1=O.CC1=CN(C...
# 510     96     ABIZUG  COCC1OC2OC3C4CNC(=O)c5cccc(n5)c5cccc(n5)C(=O)N...
# 512     98     ABMHAL  CN1C(=O)N(C)C2=C(N(C(C)=O)c3cc(C)c(C)c(Br)c3N2...
# 513     99     ABMHFO               CCCC(OC(C)=O)C1=C(Br)C(CBr)(OC)OC1=O
# 514    100     ABMPAZ      CC(=O)OC1=CN=CN(C(=O)c2ccccc2)C(=C1C)c1ccccc1
# 536      8     ABODOO  Brc1ccc(cc1)N1C(=O)N(C(=O)N(C1=O)c1ccc(Br)cc1)...
# 549     21     ABOGUW                   Brc1ccc(cc1)C1=C2Cc3ccccc3C2=NN1
# 558     30     ABOHUV  CCC(CC)[n+]1ccc(cc1)C=Cc1ccc(OC)cc1.O.O.[Br-]....
# 577     49     ABONAG  Nc1cccc(NC(=O)c2cccc(n2)C(=O)Nc2cccc(NC(=O)c3c...
# 669     29   ABPACH10  CC1C(CCC2C1(C)CCC1C2(C)CCC2(C)C3CC(C)(C)CCC3(C...
# 673     33     ABRAHE  CC1C2CCC3C45COC(OC(=O)CBr)C4C(C)(C)C(CC5OC(=O)...
# 675     35     ABRTOL                                     Cc1cc(Br)ccc1N
# 676     36     ABSBPP  CN(C)C1=C(C(=CN1C(C)(C)C)NS(=O)(=O)c1ccccc1)c1...
# 677     37     ABSCIC             CC(C=CC1(O)C(=CC(=O)CC1(C)C)C)=CC(O)=O
# 681     41   ABSINT10  CC1C2CCC(C)(O)C3C4C5C=C(C)C6(C7OC(=O)C(C)C7CCC...
# 682     42     ABTBTR      CN(C)C(=C=C=S)C(C)(C)C.CN(C)C(=C=C=S)C(C)(C)C
# 684     44     ABTOET       CCOC(=O)C1(SCCS1)C1CC(O)C2OC(OCC2O1)c1ccccc1
# 686     46   ABUBAA01  Oc1ccc(Br)cc1C=NCCN(CCN=Cc1cc(Br)ccc1O)CCN=Cc1...
# 691     51     ABUBUV  Cc1cc(C)cc(c1)c1ccc2c(c3cccc4cccc(c34)c3c4cccc...
# 695     55     ABUCIN  [O-]c1ccc2ccccc2c1C=[NH+]c1ccccc1Oc1ccccc1Oc1c...
# 721     81     ABUHOU  ClC1=C([O-])C(=O)C(=C([O-])C1=O)Cl.[nH+]1cccc(...
# 849     99     ABVPRO        CC(=O)N1CC(=CC1=O)C(=Cc1ccccc1)c1ccc(Br)cc1
# 850    100     ABXBPC  [Na+].CC(C)CCOc1ccc(CC=C)c2OC(=CC(=O)c12)C(=O)...
#
#      csd_spacegroup                                        wyckoff_spg  \
# 8                33                      A8BC2_oP88_33_16a_2a_4a:C-N-O
# 10               14                        A9B4C_mP56_14_9e_4e_e:C-N-O
# 130              19                  A2B22C5_oP116_19_2a_22a_5a:Br-C-O
# 151               2             A20B29C4D_aP108_2_20i_29i_4i_i:C-H-O-P
# 159              14            A2B14CD8_mP100_14_2e_14e_e_8e:Br-C-Cl-O
# 164              14                     A26BC6_mP132_14_26e_e_6e:C-N-O
# 177              61                     A16BC3_oP160_61_16c_c_3c:C-N-O
# 181               2                  A7BCD_aP80_2_28i_4i_4i_4i:C-N-O-S
# 184               2                 A7BC2D_aP44_2_14i_2i_4i_2i:C-N-O-S
# 260               2  AB23C3D21E3F7G_aP118_2_i_23i_3i_21i_3i_7i_i:Br...
# 290               2                            A21B2_aP46_2_21i_2i:C-O
# 293             146  A26BC20DE5F_hR486_146_26b_b_20b_b_5b_b:C-Cl-H-...
# 294               4                              A7B_mP96_4_42a_6a:C-O
# 299              19                           A15B2_oP68_19_15a_2a:C-O
# 307               2              A6B4C12D3_aP50_2_6i_4i_12i_3i:C-N-O-P
# 329              14    A17B16CDEF_mP148_14_17e_16e_e_e_e_e:C-H-I-N-O-S
# 339               4                   A27B2C13_mP84_4_27a_2a_13a:C-N-O
# 340               4                    AB32C14_mP94_4_a_32a_14a:Br-C-O
# 341              19            AB14C4D4_oP184_19_2a_28a_8a_8a:Br-C-N-O
# 384             146     A20B23CD2E_hR423_146_20b_23b_b_2b_b:C-H-N-O-Si
# 391              20        A33B2C42D12_oC356_20_a16c_c_21c_6c:C-Cl-H-O
# 397              19                          A31B3_oP136_19_31a_3a:C-O
# 405              19                  AB9C3D_oP56_19_a_9a_3a_a:Br-C-N-O
# 411             148      A102B102C12D_hR1302_148_34f_34f_4f_ab:C-H-N-O
# 413             148               A17B17C2_hR1296_148_34f_34f_4f:C-H-N
# 421              14                               AB_mP40_14_5e_5e:C-O
# 422              14                               AB_mP40_14_5e_5e:C-O
# 447               4  A49B4C72D8E17F4_mP308_4_49a_4a_72a_8a_17a_4a:C...
# 510               5   A138B192C13D60_mC806_5_2a68c_96c_a6c_30c:C-H-N-O
# 512              33            AB16C4D3_oP192_33_2a_32a_8a_6a:Br-C-N-O
# 513               1                    A2B12C5_aP19_1_2a_12a_5a:Br-C-O
# 514              61                   A21B2C3_oP208_61_21c_2c_3c:C-N-O
# 536             161  A3B22C3D13E3F3_hR282_161_b_a7b_b_a4b_b_b:Br-C-...
# 549              14                     AB16C2_mP76_14_e_16e_2e:Br-C-N
# 558              15  A2B38C48D2E5_mC380_15_ce_19f_24f_f_e2f:Br-C-H-N-O
# 577              15   A31B31C11D6E_mC640_15_31f_31f_11f_6f_f:C-H-N-O-S
# 669              19                    AB39C4_oP176_19_a_39a_4a:Br-C-O
# 673              19                    AB24C8_oP132_19_a_24a_8a:Br-C-O
# 675              19                         AB7C_oP36_19_a_7a_a:Br-C-N
# 676              56              A22B3C2D_oP224_56_22e_3e_2e_e:C-N-O-S
# 677              14                           A15B4_mP76_14_15e_4e:C-O
# 681              19                          A41B6_oP188_19_41a_6a:C-O
# 682               4                        A9BC_mP44_4_18a_2a_2a:C-N-S
# 684              19                   A19B6C2_oP108_19_19a_6a_2a:C-O-S
# 686               2             A3B27C4D3_aP74_2_3i_27i_4i_3i:Br-C-N-O
# 691              15        A56B52C4D3_mC460_15_2e27f_26f_2f_ef:C-H-N-O
# 695              15            A20B15CD2_mC304_15_20f_15f_f_2f:C-H-N-O
# 721               2            A9BC5DE4_aP40_2_9i_i_5i_i_4i:C-Cl-H-N-O
# 849              14                AB20CD2_mP96_14_e_20e_e_2e:Br-C-N-O
# 850               2                      A18BC6_aP50_2_18i_i_6i:C-Na-O
#
#                                          wyckoff_aflow
# 8                      A8BC2_oP88_33_16a_2a_4a:C-H-N-O
# 10                       A9B4C_mP56_14_9e_4e_e:C-H-N-O
# 130                A2B22C5_oP116_19_2a_22a_5a:Br-C-H-O
# 151            A20B29C4D_aP108_2_20i_29i_4i_i:C-H-O.-P
# 159          A2B14CD8_mP100_14_2e_14e_e_8e:Br-C-Cl-H-O
# 164                   A26BC6_mP132_14_26e_e_6e:C-H-N-O
# 177                   A16BC3_oP160_61_16c_c_3c:C-H-N-O
# 181                A7BCD_aP80_2_28i_4i_4i_4i:C-H-N-O-S
# 184               A7BC2D_aP44_2_14i_2i_4i_2i:C-H-N-O-S
# 260  AB23C3D21E3F7G_aP118_2_i_23i_3i_21i_3i_7i_i:Br...
# 290                          A21B2_aP46_2_21i_2i:C-H-O
# 293  A26BC20DE5F_hR162_146_26b_b_20b_b_5b_b:C-Cl-H-...
# 294                            A7B_mP96_4_42a_6a:C-H-O
# 299                         A15B2_oP68_19_15a_2a:C-H-O
# 307            A6B4C12D3_aP50_2_6i_4i_12i_3i:C-H-N-O-P
# 329  A17B16CDEF_mP148_14_17e_16e_e_e_e_e:C.-H.-I-N-O-S
# 339                 A27B2C13_mP84_4_27a_2a_13a:C-H-N-O
# 340                  AB32C14_mP94_4_a_32a_14a:Br-C-H-O
# 341          AB14C4D4_oP184_19_2a_28a_8a_8a:Br-C-H-N-O
# 384     A20B23CD2E_hR141_146_20b_23b_b_2b_b:C-H-N-O-Si
# 391        A33B2C42D12_oC356_20_b16c_c_21c_6c:C-Cl-H-O
# 397                        A31B3_oP136_19_31a_3a:C-H-O
# 405                AB9C3D_oP56_19_a_9a_3a_a:Br-C-H-N-O
# 411     A102B102C12D_aP434_2_102i_102i_12i_be:C-H-N-O.
# 413                A17B17C2_hR432_148_34f_34f_4f:C-H-N
# 421                             AB_mP40_14_5e_5e:C-H-O
# 422                             AB_mP40_14_5e_5e:C-H-O
# 447  A49B4C72D8E17F4_mP308_4_49a_4a_72a_8a_17a_4a:C...
# 510  A138B192C13D60_mC806_5_2a68c_96c_a6c_30c:C-H-N.-O
# 512          AB16C4D3_oP192_33_2a_32a_8a_6a:Br-C-H-N-O
# 513                  A2B12C5_aP19_1_2a_12a_5a:Br-C-H-O
# 514                 A21B2C3_oP208_61_21c_2c_3c:C-H-N-O
# 536  A3B22C3D13E3F3_hR94_161_b_a7b_b_a4b_b_b:Br-C-C...
# 549                   AB16C2_mP76_14_e_16e_2e:Br-C-H-N
# 558  A2B38C48D2E5_mC380_15_ae_19f_24f_f_e2f:Br-C-H-N-O
# 577  A31B31C11D6E_mC640_15_31f_31f_11f_6f_f:C.-H.-N...
# 669                  AB39C4_oP176_19_a_39a_4a:Br-C-H-O
# 673                  AB24C8_oP132_19_a_24a_8a:Br-C-H-O
# 675                       AB7C_oP36_19_a_7a_a:Br-C-H-N
# 676            A22B3C2D_oP224_56_22e_3e_2e_e:C-H-N-O-S
# 677                         A15B4_mP76_14_15e_4e:C-H-O
# 681                        A41B6_oP188_19_41a_6a:C-H-O
# 682                      A9BC_mP44_4_18a_2a_2a:C-H-N-S
# 684                 A19B6C2_oP108_19_19a_6a_2a:C-H-O-S
# 686           A3B27C4D3_aP74_2_3i_27i_4i_3i:Br-C-H-N-O
# 691       A56B52C4D3_mC460_15_2e27f_26f_2f_ef:C-H.-N-O
# 695           A20B15CD2_mC304_15_20f_15f_f_2f:C-H.-N-O
# 721           A9BC5DE4_aP40_2_9i_i_5i_i_4i:C-Cl-H-N-O.
# 849              AB20CD2_mP96_14_e_20e_e_2e:Br-C-H-N-O
# 850                    A18BC6_aP50_2_18i_i_6i:C-H-Na-O

# %%
from ccdc import io, utilities
import re 

csd_reader = io.EntryReader()

entry_name = 'ABIMUW'
entry = csd_reader.entry(entry_name)
crystal = entry.crystal

print(f'SMILES: {crystal.molecule.smiles}')
print(f'Crystal System: {crystal.crystal_system}')
print(f'Spacegroup Symbol: {crystal.spacegroup_symbol}')
print(f'Spacegroup Number: {crystal.spacegroup_number_and_setting}')
print(f'Has disorder: {crystal.has_disorder}')
print(f'Disorder details: {entry.disorder_details}')

elems = [re.sub("([A-Z]).*", r"\1", elem) for elem in crystal.formula.split(" ")]
print(f'Sorted elements: {sorted(elems)}')

print('\n'.join('%-17s %s' % (op, utilities.print_set(crystal.atoms_on_special_positions(op))) for op in crystal.symmetry_operators))

# cif_string = crystal.to_string(format='cif')
# with open('tmp.cif', 'w') as f:
#     f.write(cif_string)
# Out:
# SMILES: C1CCC2N=Cc3cc4C=NC5CCCCC5N=Cc5cc6C=NC7CCCCC7N=Cc7cc(C=NC2C1)cc(c7)c1ccc(cc1)c1cc2C=NC7CCCCC7N=Cc7cc(C=NC8CCCCC8N=Cc8cc(C=NC9CCCCC9N=Cc(c2)c1)cc(c8)c1ccc(cc1)c(c6)c5)cc(c7)c1ccc(cc1)c(c3)c4.O.O
# Crystal System: rhombohedral
# Spacegroup Symbol: R-3
# Spacegroup Number: (148, 1)
# Has disorder: False
# Disorder details: None
# Sorted elements: ['C', 'H', 'N', 'O']
# x,y,z             {Atom(C1), Atom(C10), Atom(C10A), Atom(C10B), Atom(C11), Atom(C11A), Atom(C11B), Atom(C12), Atom(C12A), Atom(C12B), Atom(C13), Atom(C13A), Atom(C13B), Atom(C14), Atom(C14A), Atom(C14B), Atom(C15), Atom(C15A), Atom(C15B), Atom(C16), Atom(C16A), Atom(C16B), Atom(C17), Atom(C17A), Atom(C17B), Atom(C18), Atom(C18A), Atom(C18B), Atom(C19), Atom(C19A), Atom(C19B), Atom(C1A), Atom(C1B), Atom(C2), Atom(C20), Atom(C20A), Atom(C20B), Atom(C21), Atom(C21A), Atom(C21B), Atom(C22), Atom(C22A), Atom(C22B), Atom(C23), Atom(C23A), Atom(C23B), Atom(C24), Atom(C24A), Atom(C24B), Atom(C25), Atom(C25A), Atom(C25B), Atom(C26), Atom(C26A), Atom(C26B), Atom(C27), Atom(C27A), Atom(C27B), Atom(C28), Atom(C28A), Atom(C28B), Atom(C29), Atom(C29A), Atom(C29B), Atom(C2A), Atom(C2B), Atom(C3), Atom(C30), Atom(C30A), Atom(C30B), Atom(C31), Atom(C31A), Atom(C31B), Atom(C32), Atom(C32A), Atom(C32B), Atom(C33), Atom(C33A), Atom(C33B), Atom(C34), Atom(C34A), Atom(C34B), Atom(C3A), Atom(C3B), Atom(C4), Atom(C4A), Atom(C4B), Atom(C5), Atom(C5A), Atom(C5B), Atom(C6), Atom(C6A), Atom(C6B), Atom(C7), Atom(C7A), Atom(C7B), Atom(C8), Atom(C8A), Atom(C8B), Atom(C9), Atom(C9A), Atom(C9B), Atom(H1), Atom(H10), Atom(H10A), Atom(H10B), Atom(H11), Atom(H11A), Atom(H11B), Atom(H12), Atom(H12A), Atom(H12B), Atom(H13), Atom(H13A), Atom(H13B), Atom(H14), Atom(H14A), Atom(H14B), Atom(H15), Atom(H15A), Atom(H15B), Atom(H16), Atom(H16A), Atom(H16B), Atom(H17), Atom(H17A), Atom(H17B), Atom(H18), Atom(H18A), Atom(H18B), Atom(H19), Atom(H19A), Atom(H19B), Atom(H1A), Atom(H1B), Atom(H2), Atom(H20), Atom(H20A), Atom(H20B), Atom(H21), Atom(H21A), Atom(H21B), Atom(H22), Atom(H22A), Atom(H22B), Atom(H23), Atom(H23A), Atom(H23B), Atom(H24), Atom(H24A), Atom(H24B), Atom(H25), Atom(H25A), Atom(H25B), Atom(H26), Atom(H26A), Atom(H26B), Atom(H27), Atom(H27A), Atom(H27B), Atom(H28), Atom(H28A), Atom(H28B), Atom(H29), Atom(H29A), Atom(H29B), Atom(H2A), Atom(H2B), Atom(H3), Atom(H30), Atom(H30A), Atom(H30B), Atom(H31), Atom(H31A), Atom(H31B), Atom(H32), Atom(H32A), Atom(H32B), Atom(H33), Atom(H33A), Atom(H33B), Atom(H34), Atom(H34A), Atom(H34B), Atom(H3A), Atom(H3B), Atom(H4), Atom(H4A), Atom(H4B), Atom(H5), Atom(H5A), Atom(H5B), Atom(H6), Atom(H6A), Atom(H6B), Atom(H7), Atom(H7A), Atom(H7B), Atom(H8), Atom(H8A), Atom(H8B), Atom(H9), Atom(H9A), Atom(H9B), Atom(N1), Atom(N1A), Atom(N1B), Atom(N2), Atom(N2A), Atom(N2B), Atom(N3), Atom(N3A), Atom(N3B), Atom(N4), Atom(N4A), Atom(N4B), Atom(O1), Atom(O2)}
# -y,x-y,z          set()
# -x+y,-x,z         set()
# 2/3+x,1/3+y,1/3+z set()
# 2/3-y,1/3+x-y,1/3+z set()
# 2/3-x+y,1/3-x,1/3+z set()
# 1/3+x,2/3+y,2/3+z set()
# 1/3-y,2/3+x-y,2/3+z set()
# 1/3-x+y,2/3-x,2/3+z set()
# -x,-y,-z          set()
# y,-x+y,-z         set()
# x-y,x,-z          set()
# 1/3-x,2/3-y,2/3-z set()
# 1/3+y,2/3-x+y,2/3-z set()
# 1/3+x-y,2/3+x,2/3-z set()
# 2/3-x,1/3-y,1/3-z set()
# 2/3+y,1/3-x+y,1/3-z set()
# 2/3+x-y,1/3+x,1/3-z set()
